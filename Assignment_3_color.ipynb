# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm

DATADIR = "kaggle-one-shot-pokemon/"

CATEGORIES = ["pokemon-a", "pokemon-b"]

for category in CATEGORIES:  # do dogs and cats
    path = os.path.join(DATADIR,category)  # create path to dogs and cats
    for img in os.listdir(path):  # iterate over each image per dogs and cats
        img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)  # convert to array
        plt.imshow(img_array)  # graph it
        plt.show()  # display!

        break  # we just want one for now so break
    break  #...and one more!

# %%
print(img_array.shape)
# Out:
# (300, 300)

# %%
IMG_SIZE = 50

new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array)
plt.show()

# %%
new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array)
plt.show()

# %%
training_data = []

def create_training_data():
    for category in CATEGORIES:  # do dogs and cats

        path = os.path.join(DATADIR,category)  # create path to dogs and cats
        class_num = CATEGORIES.index(category)  # get the classification  (0 or a 1). 0=dog 1=cat

        for img in tqdm(os.listdir(path)):  # iterate over each image per dogs and cats
            try:
                img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)  # convert to array
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize to normalize data size
                training_data.append([new_array, class_num])  # add this to our training_data
            except Exception as e:  # in the interest in keeping the output clean...
                pass
            #except OSError as e:
            #    print("OSErrroBad img most likely", e, os.path.join(path,img))
            #except Exception as e:
            #    print("general exception", e, os.path.join(path,img))

create_training_data()

print(len(training_data))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 939/939 [00:00<00:00, 1208.56it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 819/819 [00:04<00:00, 174.13it/s]
# 1758

# %%
import random

random.shuffle(training_data)

# %%
for sample in training_data[:10]:
    print(sample[1])
# Out:
# 1
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 0
# 1

# %%
X = []
y = []

for features,label in training_data:
    X.append(features)
    y.append(label)

print(X[0].reshape(-1, IMG_SIZE, IMG_SIZE, 1))

X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
# Out:
# [[[[255]
#    [255]
#    [255]
#    ...
#    [255]
#    [255]
#    [255]]
#
#   [[255]
#    [255]
#    [255]
#    ...
#    [255]
#    [255]
#    [255]]
#
#   [[255]
#    [255]
#    [255]
#    ...
#    [255]
#    [255]
#    [255]]
#
#   ...
#
#   [[255]
#    [255]
#    [255]
#    ...
#    [255]
#    [255]
#    [255]]
#
#   [[255]
#    [255]
#    [255]
#    ...
#    [255]
#    [255]
#    [255]]
#
#   [[255]
#    [255]
#    [255]
#    ...
#    [255]
#    [255]
#    [255]]]]

# %%
X.shape
# Out:
# (1758, 50, 50, 1)

# %%
import pickle

pickle_out = open("X.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

import pickle

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

model = Sequential()

model.add(Conv2D(256, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

model.add(Dense(64))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(X, y, batch_size=32, epochs=3, validation_split=0.3)
# Out:
# Train on 1230 samples, validate on 528 samples
# Epoch 1/3
# 1230/1230 [==============================] - ETA: 36s - loss: 0.7039 - acc: 0.28 - ETA: 27s - loss: 0.8358 - acc: 0.43 - ETA: 24s - loss: 2.2765 - acc: 0.45 - ETA: 22s - loss: 2.0445 - acc: 0.48 - ETA: 21s - loss: 1.7227 - acc: 0.57 - ETA: 19s - loss: 1.5058 - acc: 0.63 - ETA: 18s - loss: 1.3385 - acc: 0.66 - ETA: 18s - loss: 1.3679 - acc: 0.64 - ETA: 17s - loss: 1.2609 - acc: 0.65 - ETA: 16s - loss: 1.1812 - acc: 0.68 - ETA: 15s - loss: 1.0900 - acc: 0.70 - ETA: 15s - loss: 1.0272 - acc: 0.72 - ETA: 14s - loss: 0.9643 - acc: 0.74 - ETA: 13s - loss: 0.9516 - acc: 0.72 - ETA: 13s - loss: 0.8990 - acc: 0.73 - ETA: 12s - loss: 0.8782 - acc: 0.74 - ETA: 12s - loss: 0.8513 - acc: 0.75 - ETA: 11s - loss: 0.8481 - acc: 0.75 - ETA: 10s - loss: 0.8157 - acc: 0.76 - ETA: 10s - loss: 0.7873 - acc: 0.77 - ETA: 9s - loss: 0.7618 - acc: 0.7783 - ETA: 9s - loss: 0.7412 - acc: 0.784 - ETA: 8s - loss: 0.7196 - acc: 0.788 - ETA: 8s - loss: 0.6985 - acc: 0.793 - ETA: 7s - loss: 0.6784 - acc: 0.798 - ETA: 6s - loss: 0.6677 - acc: 0.801 - ETA: 6s - loss: 0.6457 - acc: 0.807 - ETA: 5s - loss: 0.6241 - acc: 0.813 - ETA: 5s - loss: 0.6230 - acc: 0.814 - ETA: 4s - loss: 0.6143 - acc: 0.816 - ETA: 4s - loss: 0.6055 - acc: 0.818 - ETA: 3s - loss: 0.5948 - acc: 0.821 - ETA: 3s - loss: 0.5866 - acc: 0.821 - ETA: 2s - loss: 0.5778 - acc: 0.823 - ETA: 1s - loss: 0.5683 - acc: 0.825 - ETA: 1s - loss: 0.5587 - acc: 0.830 - ETA: 0s - loss: 0.5516 - acc: 0.832 - ETA: 0s - loss: 0.5405 - acc: 0.835 - 25s 20ms/sample - loss: 0.5364 - acc: 0.8366 - val_loss: 0.1971 - val_acc: 0.9167
# Epoch 2/3
# 1230/1230 [==============================] - ETA: 22s - loss: 0.4340 - acc: 0.81 - ETA: 20s - loss: 0.3016 - acc: 0.87 - ETA: 20s - loss: 0.2527 - acc: 0.89 - ETA: 19s - loss: 0.2103 - acc: 0.91 - ETA: 18s - loss: 0.2466 - acc: 0.90 - ETA: 18s - loss: 0.2402 - acc: 0.90 - ETA: 17s - loss: 0.2242 - acc: 0.90 - ETA: 16s - loss: 0.2309 - acc: 0.90 - ETA: 16s - loss: 0.2261 - acc: 0.89 - ETA: 15s - loss: 0.2198 - acc: 0.90 - ETA: 15s - loss: 0.2119 - acc: 0.91 - ETA: 14s - loss: 0.2159 - acc: 0.91 - ETA: 14s - loss: 0.2164 - acc: 0.91 - ETA: 13s - loss: 0.2112 - acc: 0.91 - ETA: 12s - loss: 0.2091 - acc: 0.91 - ETA: 12s - loss: 0.2076 - acc: 0.91 - ETA: 11s - loss: 0.1976 - acc: 0.92 - ETA: 11s - loss: 0.1911 - acc: 0.92 - ETA: 10s - loss: 0.1931 - acc: 0.92 - ETA: 10s - loss: 0.1906 - acc: 0.92 - ETA: 9s - loss: 0.1955 - acc: 0.9211 - ETA: 9s - loss: 0.2045 - acc: 0.917 - ETA: 8s - loss: 0.2077 - acc: 0.917 - ETA: 7s - loss: 0.2184 - acc: 0.912 - ETA: 7s - loss: 0.2220 - acc: 0.912 - ETA: 6s - loss: 0.2201 - acc: 0.913 - ETA: 6s - loss: 0.2170 - acc: 0.914 - ETA: 5s - loss: 0.2152 - acc: 0.915 - ETA: 5s - loss: 0.2191 - acc: 0.913 - ETA: 4s - loss: 0.2236 - acc: 0.912 - ETA: 4s - loss: 0.2225 - acc: 0.913 - ETA: 3s - loss: 0.2252 - acc: 0.912 - ETA: 2s - loss: 0.2259 - acc: 0.911 - ETA: 2s - loss: 0.2243 - acc: 0.912 - ETA: 1s - loss: 0.2257 - acc: 0.912 - ETA: 1s - loss: 0.2265 - acc: 0.911 - ETA: 0s - loss: 0.2242 - acc: 0.912 - ETA: 0s - loss: 0.2232 - acc: 0.912 - 25s 20ms/sample - loss: 0.2222 - acc: 0.9138 - val_loss: 0.1713 - val_acc: 0.9337
# Epoch 3/3
# 1230/1230 [==============================] - ETA: 22s - loss: 0.1730 - acc: 0.96 - ETA: 20s - loss: 0.1701 - acc: 0.95 - ETA: 19s - loss: 0.1804 - acc: 0.93 - ETA: 19s - loss: 0.2079 - acc: 0.92 - ETA: 18s - loss: 0.2466 - acc: 0.90 - ETA: 17s - loss: 0.2280 - acc: 0.90 - ETA: 17s - loss: 0.2091 - acc: 0.91 - ETA: 16s - loss: 0.1974 - acc: 0.92 - ETA: 16s - loss: 0.2084 - acc: 0.92 - ETA: 15s - loss: 0.2074 - acc: 0.92 - ETA: 15s - loss: 0.2030 - acc: 0.92 - ETA: 14s - loss: 0.2007 - acc: 0.92 - ETA: 14s - loss: 0.1989 - acc: 0.93 - ETA: 13s - loss: 0.1932 - acc: 0.93 - ETA: 12s - loss: 0.1921 - acc: 0.93 - ETA: 12s - loss: 0.1902 - acc: 0.93 - ETA: 11s - loss: 0.1827 - acc: 0.93 - ETA: 11s - loss: 0.1758 - acc: 0.94 - ETA: 10s - loss: 0.1739 - acc: 0.94 - ETA: 10s - loss: 0.1753 - acc: 0.94 - ETA: 9s - loss: 0.1773 - acc: 0.9390 - ETA: 9s - loss: 0.1767 - acc: 0.940 - ETA: 8s - loss: 0.1821 - acc: 0.937 - ETA: 7s - loss: 0.1811 - acc: 0.937 - ETA: 7s - loss: 0.1773 - acc: 0.938 - ETA: 6s - loss: 0.1785 - acc: 0.937 - ETA: 6s - loss: 0.1783 - acc: 0.936 - ETA: 5s - loss: 0.1765 - acc: 0.937 - ETA: 5s - loss: 0.1790 - acc: 0.936 - ETA: 4s - loss: 0.1764 - acc: 0.937 - ETA: 4s - loss: 0.1735 - acc: 0.939 - ETA: 3s - loss: 0.1720 - acc: 0.939 - ETA: 2s - loss: 0.1701 - acc: 0.939 - ETA: 2s - loss: 0.1734 - acc: 0.938 - ETA: 1s - loss: 0.1772 - acc: 0.936 - ETA: 1s - loss: 0.1741 - acc: 0.938 - ETA: 0s - loss: 0.1740 - acc: 0.938 - ETA: 0s - loss: 0.1727 - acc: 0.937 - 25s 20ms/sample - loss: 0.1717 - acc: 0.9382 - val_loss: 0.1575 - val_acc: 0.9318
